# %%
f = open("1.txt","r+")

f.write("dev\n")
f.seek(0)
x=f.read()
f.close()
print(x)
# Out:
# dev
# hello
# hi

# %%
f= open("3.txt")
x = f.read()
f.close()

f = open("4.txt","w")
f.write(x)
f.close()

# %%
y="jay shree ram\nhello how are you"
f= open("5.txt","w+")
f.write(y)
f.seek(0)
x = f.read()
f.close()
x = x[::-1]
f = open("6.txt","w")
f.write(x)
f.close()

# %%
f = open("7.txt","w+")
f.write("1\n2\n3\n4\n5\n")
f.seek(0)
a =f.read()
f.close()

f = open("8.txt","w+")
f.write("1\n2\n3\n4\n5\n")
f.seek(0)
b =f.read()
f.close()

f= open("9.txt","w")
f.write(a)
f.write(b)
f.close()

# %%
f = open("1.txt","r")

x = f.read(7)
print(x)
# Out:
# dev
# hel

# %%
x = 10000
n = 5
m = 24

hit=1

gain = ((m/(n*n))*hit)*x

print(x+gain)
# Out:
# 19600.0

# %%
# Out:
# 25
