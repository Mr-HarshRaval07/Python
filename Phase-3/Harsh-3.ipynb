# %%
import os

# %%
os.getcwd()

# %%
os.mkdir("huihuihui")

# %%
os.chdir(os.getcwd()+"//huihuihui")

# %%
os.getcwd()

# %%
# %%writefile 1.txt
# hola

# %%
os.rename("1.txt","demo.txt")

# %%
os.remove("demo.txt")

# %%
os.listdir( )

# %%
os.rmdir(os.getcwd())

# %%
os.getcwd()
os.chdir(r"C:\\Users\\LJENG\\Desktop\\Dev B4\\PYTHON")

# %%
os.rmdir(r"C:\\Users\\LJENG\\Desktop\\Dev B4\\PYTHON\\huihuihui")

# %%
# %%writefile demo.py
def lenth(s):
    return len(s)

# %%
import demo as e
s= "dev"
e.lenth(s)

# %%
# %%writefile first_word.py
def one(s):
    s = s.split(" ")
    return(s[0])
# Out:
# Overwriting first_word.py

# %%
import first_word as f
x = "pasu is good boy"
print(f.one(x))
# Out:
# pasu
