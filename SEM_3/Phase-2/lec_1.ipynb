# %%
x="Happy NEW Year"
print(x[0:13])
print(x[0:500])
print(x[6::10])
print(x[-1:-4:-1])
print(x[-1:-10:-2])
print(x[:])
# Out:
# Happy NEW Yea
# Happy NEW Year
# N
# rae
# re
# Happy NEW Year

# %%
x="lassi"
y=len(x)
print(y)
if(y%2==0):
    print(x[0],x[-1])
else:
    print(x[-1]+x[1:-1]+x[0])
# Out:
# 5
# iassl

# %%
x="dhruv dhoni virat"
print(x.count("d",0,3))
print(x.replace("dhruv","@"))
print(x.split("r"))
print("-".join(x))
# Out:
# 1
# @ dhoni virat
# ['dh', 'uv dhoni vi', 'at']
# d-h-r-u-v- -d-h-o-n-i- -v-i-r-a-t

# %%
x="hyyy harsh what"
y=len(x)
print(y)
if(y%2!=0):
    z=x.replace("a","@")
    z.lower()
    print(z)
else:
    z=x.split("a")
    b=x.split(" ")
    print(z)
    print(b)
# Out:
# 15
# hyyy h@rsh wh@t

# %%
x="dhruv dhoni"
y=x.find("r")
if y==-1:
    print("not found")
else:
    print(y)
# Out:
# not found

# %%
x="welcomenewyear"
print(x.isalnum())
print(x.isalpha())
print(x.isdigit())
print(x.isnumeric())
print(x.isupper())
print(x.islower())
print(x.istitle())
# Out:
# True
# True
# False
# False
# False
# True
# False
