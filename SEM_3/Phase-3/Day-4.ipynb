# %%
try:
    a=10
    b=0
    print(a/b)
    l=[1,2,3,4]
    print(l)
except Exception as e:
    print(e)

# %%
class InvalidNum(Exception):
    pass

try:
    num = int(input("Enter number"))
    num = str(num)
    if(len(num)!=10 and num[0]!=9):
        raise InvalidNum("Invalid number")
except Exception as e:
    print(e)
# Out:
# Enter number938495
# Invalid number

# %%
import datetime as dt

x= dt.datetime.now()

print(x)
print(x.year)
print(x.month)
print(x.day)

y=dt.date.today()
print(y)
# Out:
# 2025-12-04 13:22:38.357188
# 2025
# 12
# 4
# 2025-12-04

# %%
year = int(input("Enter Birth year"))
month = int(input("Enter Birth Month"))
day = int(input("Enter Birth Day"))

z=date(year,month,day)

y=dt.date.today()

print(y-z)
# Out:
# Enter Birth year2006
