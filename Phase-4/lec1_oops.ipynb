# %%
class a:
    def show(self):
        print("A show")
class b(a):
    def selfie(self):
        print("B selfie")
B=b()
B.show()
B.selfie()
# Out:
# A show
# B selfie

# %%
class a:
    def show(self):
        print("A show")
class b(a):
    def selfie(self):
        super().show()
        print("B selfie")
B=b()
B.selfie()
# Out:
# A show
# B selfie

# %%
class a:
    def __init__(self):
        print("A constructor")
    def show(self):
        print("A show")
class b(a):
    def selfie(self):
        super().show()
        print("B selfie")
B=b()
B.selfie()
# Out:
# A constructor
# A show
# B selfie

# %%
class a:
    def __init__(self):
        print("A constructor")
    def show(self):
        print("A show")
class b(a):
    def __init__(self):
        print("B constructor")
    def selfie(self):
        super().show()
        print("B selfie")
B=b()
B.selfie()
# Out:
# B constructor
# A show
# B selfie

# %%
class a:
    def __init__(self,a,b):
        print("A constructor")
    def show(self):
        print("A show")
class b(a):
    def __init__(self,a):
        print("B constructor")
    def selfie(self):
        #super().show()
        print("B selfie")
B=b(10)
B.selfie()
# Out:
# B constructor
# B selfie

# %%
class a:
    def __init__(self,a,b):
        print("A constructor")
    def show(self):
        print("A show")
class b(a):
    def selfie(self):
        #super().show()
        print("B selfie")
B=b(10,20)
B.selfie()
# Out:
# A constructor
# B selfie

# %%
class a1:
    def __init__(self):
        print("A1 const")
    def show(self):
        print("Show a1")
class a2(a1):
    def __init__(self):
        print("A2 const")
    def show(self):
        print("Show a2")
class a3(a2):
    def __init__(self):
        print("A3 const")
    def show(self):
        print("Show a3")

a=a3()
a.show()
# Out:
# A3 const
# Show a3

# %%
class a1:
    def __init__(self):
        print("A1 const")
    def show(self):
        print("Show a1")
class a2(a1):
    def __init__(self):
        print("A2 const")
    def show(self):
        print("Show a2")
class a3(a2):
    def __init__(self):
        super().__init__()
        print("A3 const")
    def show(self):
        print("Show a3")

a=a3()
a.show()
# Out:
# A2 const
# A3 const
# Show a3

# %%
class a1:
    def __init__(self):
        print("A1 const")
    def show(self):
        print("Show a1")
class a2(a1):
    pass
class a3(a2):
    def __init__(self):
        super().__init__()
        print("A3 const")
    def show(self):
        print("Show a3")

a=a3()
a.show()
# Out:
# A1 const
# A3 const
# Show a3

# %%
class st:
    def __init__(self,mark):
        self.mark=mark
    def __str__(self):
        return "hello"
    def __ge__(self,other):
        return "bool "
s=st(10)
print(s)
s1=st(70)
s2=st(100)
print(s1>=s2)
# Out:
# hello
# bool

# %% [raw]
# multiple inh
# multi level
# __mro__
# polymorphism
