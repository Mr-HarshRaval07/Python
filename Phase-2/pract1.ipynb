# %%
s1='box'
s2='boy'
if s1<s2:
    print("S1 is less than S2")
else:
    print("S1 is greater than equal to S2")
# Out:
# S1 is less than S2

# %%
#rfind
str=input('Enter main string')
sub=input("Enter sub string")
n=str.rfind(sub,0,len(str))
if n==-1:
    print('No occurance')
else:
    print('Index found at ',n+1)
# Out:
# Enter main string This is python
# Enter sub string is
# Index found at  6

# %%
a=eval(input('Enter data'))
print(type(a))
# Out:
# Enter data [1,2,3]
# <class 'list'>

# %%
#Encryption program
s=input('Enter string')
k=int(input('Enter key'))
l=""
o1=ord("A")
o2=ord("a")
for i in s:
    o1=ord("A")
    o2=ord("a")
    of=0
    if i.isupper():
        of=ord(i)+k
        if of >ord("Z"):
            of=of-26
        l+=chr(of)
    elif i.islower():
        of=ord(i)+k
        if of>ord("z"):
            of=of-26
        l+=chr(of)
    else:
        l+=" "
print(l)
# Out:
# Enter string ABc Hr kR
# Enter key 3
# DEf Ku nU

# %%
#max freq in string
s=input("enter string:")
l=[]
flag=0
for i in range(len(s)):
    flag=0
    x=s.count(s[i])
    for j in range(i):
        if s[i]==s[j]:
            flag=1
    if flag==0:
        print("Character ",s[i], "occur s",x,"times.")
# Out:
# enter string: thisis string charactertest
# Character  t occur  5 times.
# Character  h occur  2 times.
# Character  i occur  3 times.
# Character  s occur  4 times.
# Character    occur  2 times.
# Character  r occur  3 times.
# Character  n occur  1 times.
# Character  g occur  1 times.
# Character  c occur  2 times.
# Character  a occur  2 times.
# Character  e occur  2 times.

# %%
#Dictionary
x={}
n=int(input('Enter number of players:'))
for i in range(n):
    name=input('Enter player name:')
    runs=int(input('Enter player runs:'))
    x.update({name:runs})
print('Players in match:')
for pname in x.keys():
    print(pname)
# Out:
# Enter number of players: 2
# Enter player name: Virat
# Enter player runs: 100
# Enter player name: Rohit
# Enter player runs: 99
# Players in match:
# Virat
# Rohit
